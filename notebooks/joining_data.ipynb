# %% [markdown]
# Join the data from Part 1 with the data from Part 2 to create a new dataframe.

# %%
import pandas as pd

# Load the DataFrame from the Miami Bikes pickle file
df1 = pd.read_pickle('samples_3_Miami_Bikes.pk')
df1.head()
# Out:
#                    City             CityLatLon       Company  \
# 0  Miami Beach, Florida  25.790654,-80.1300455  DecoBike LLC
# 1  Miami Beach, Florida  25.790654,-80.1300455  DecoBike LLC
# 2  Miami Beach, Florida  25.790654,-80.1300455  DecoBike LLC
#
#                        Bike_Stations   latitude  longitude  free_bikes  \
# 0    605 - Virginia St & Florida Ave  25.729275 -80.241581          16
# 1  606 - S Bayshor Dr & Aviation Ave  25.732522 -80.233244           7
# 2                    608 - City Hall  25.728437 -80.234443          12
#
#    empty_slots
# 0            0
# 1            9
# 2            4

# %%
#Using 3 Stations
station1_bikes = df1.loc[0:0]
station2_bikes = df1.loc[1:1]
station3_bikes = df1.loc[2:2]

# %%
# Load the DataFrame from YELP_Miami_Bike station 1 pickle file
station1_yelp = pd.read_pickle('YELP_station_Miami_Bikes_Station1.pk')
station2_yelp = pd.read_pickle('YELP_station_Miami_Bikes_Station2.pk')
station3_yelp = pd.read_pickle('YELP_station_Miami_Bikes_Station3.pk')

# %%
#station1combined_df 
# Repeat the single-row DataFrame to match the number of rows in df2
station1_bikes_repeated = pd.concat([station1_bikes] * len(station1_yelp), ignore_index=True)

# Concatenate the two DataFrames horizontally
station1combined_df= pd.concat([station1_bikes_repeated, station1_yelp], axis=1)
#station1combined_df

# %%
#station2combined_df

# Repeat the single-row DataFrame to match the number of rows in df2
station2_bikes_repeated = pd.concat([station2_bikes] * len(station2_yelp), ignore_index=True)

# Concatenate the two DataFrames horizontally
station2combined_df= pd.concat([station2_bikes_repeated, station2_yelp], axis=1)
#station2combined_df

# %%
#station3combined_df

# Repeat the single-row DataFrame to match the number of rows in df2
station3_bikes_repeated = pd.concat([station3_bikes] * len(station3_yelp), ignore_index=True)

# Concatenate the two DataFrames horizontally
station3combined_df= pd.concat([station3_bikes_repeated, station3_yelp], axis=1)
#station3combined_df

# %%
#ALL STATIONS COMBINED

All_3_Miami_Stations_Combined = pd.concat([station1combined_df,station2combined_df,station3combined_df], axis=0, ignore_index=True)
All_3_Miami_Stations_Combined.head(1)
# Out:
#                    City             CityLatLon       Company  \
# 0  Miami Beach, Florida  25.790654,-80.1300455  DecoBike LLC
#
#                      Bike_Stations   latitude  longitude  free_bikes  \
# 0  605 - Virginia St & Florida Ave  25.729275 -80.241581          16
#
#    empty_slots                      id                  alias  ...  \
# 0            0  V3btCvWa1flTBYt2YKea_g  bombay-darbar-miami-3  ...
#
#   location.address2 location.address3  location.city location.zip_code  \
# 0                                              Miami             33133
#
#    location.country  location.state           location.display_address  \
# 0                US              FL  2901 Florida Ave, Miami, FL 33133
#
#   Category 1 Category 2 Category 3
# 0     indpak       None       None
#
# [1 rows x 34 columns]

# %%
#All_3_Miami_Stations_Combined.info()

# %%
All_3_Miami_Stations_Combined=All_3_Miami_Stations_Combined[['City','CityLatLon','Company','Bike_Stations','latitude','longitude',
                                                                   'free_bikes','empty_slots','id','name','review_count','rating',
                                                                         'coordinates.latitude','coordinates.longitude','location.display_address',
                                                            'Category 1','Category 2', 'Category 3']]
All_3_Miami_Stations_Combined.head()
# Out:
#                    City             CityLatLon       Company  \
# 0  Miami Beach, Florida  25.790654,-80.1300455  DecoBike LLC
# 1  Miami Beach, Florida  25.790654,-80.1300455  DecoBike LLC
# 2  Miami Beach, Florida  25.790654,-80.1300455  DecoBike LLC
# 3  Miami Beach, Florida  25.790654,-80.1300455  DecoBike LLC
# 4  Miami Beach, Florida  25.790654,-80.1300455  DecoBike LLC
#
#                      Bike_Stations   latitude  longitude  free_bikes  \
# 0  605 - Virginia St & Florida Ave  25.729275 -80.241581          16
# 1  605 - Virginia St & Florida Ave  25.729275 -80.241581          16
# 2  605 - Virginia St & Florida Ave  25.729275 -80.241581          16
# 3  605 - Virginia St & Florida Ave  25.729275 -80.241581          16
# 4  605 - Virginia St & Florida Ave  25.729275 -80.241581          16
#
#    empty_slots                      id                        name  \
# 0            0  V3btCvWa1flTBYt2YKea_g               Bombay Darbar
# ...

# %%
All_3_Miami_Stations_Combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   City                      150 non-null    object
#  1   CityLatLon                150 non-null    object
#  2   Company                   150 non-null    object
#  3   Bike_Stations             150 non-null    object
#  4   latitude                  150 non-null    float64
#  5   longitude                 150 non-null    float64
#  6   free_bikes                150 non-null    int64
#  7   empty_slots               150 non-null    int64
#  8   id                        150 non-null    object
#  9   name                      150 non-null    object
#  10  review_count              150 non-null    int64
#  11  rating                    150 non-null    float64
#  12  coordinates.latitude      150 non-null    float64
# ...

# %%
groupeddata = All_3_Miami_Stations_Combined.groupby('Bike_Stations')
print(groupeddata.size())
# Out:
# Bike_Stations
# 605 - Virginia St & Florida Ave      50
# 606 - S Bayshor Dr & Aviation Ave    50
# 608 - City Hall                      50
# dtype: int64

# %%
grouped_data['review_count'].sum()
# Out:
# Bike_Stations
# 605 - Virginia St & Florida Ave      19838
# 606 - S Bayshor Dr & Aviation Ave    15907
# 608 - City Hall                      18702
# Name: review_count, dtype: int64

# %%
grouped_data['rating'].mean()
# Out:
# Bike_Stations
# 605 - Virginia St & Florida Ave      4.03
# 606 - S Bayshor Dr & Aviation Ave    4.06
# 608 - City Hall                      4.04
# Name: rating, dtype: float64

# %%
import matplotlib.pyplot as plt

# Define the data
review_counts = [19838, 15907, 18702]
ratings = [4.03, 4.06, 4.04]
bike_stations = ['605 - Virginia St & Florida Ave', '606 - S Bayshor Dr & Aviation Ave', '608 - City Hall']

# Create a figure and axes
fig, ax = plt.subplots()

# Plot the review counts
ax.bar(bike_stations, review_counts, width = 0.25 ,color='black', label='Review Count')

# Plot the ratings
ax.bar(bike_stations, ratings, width = 1.15, color='red', label='Rating')

# Set labels and title
ax.set_xlabel('Bike Stations')
ax.set_ylabel('Count / Rating')
ax.set_title('Review Count and Rating by Bike Stations')
ax.legend()

# Rotate the x-axis labels
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the data
review_counts = [19838, 15907, 18702]
ratings = [4.03, 4.06, 4.04]
bike_stations = ['605 - Virginia St & Florida Ave', '606 - S Bayshor Dr & Aviation Ave', '608 - City Hall']

# Set the width of each bar
bar_width = 0.15

# Create an array of indices for the x-axis locations
indices = np.arange(len(bike_stations))

# Create the figure and axes
fig, ax1 = plt.subplots()

# Plot the review counts
ax1.bar(indices, review_counts, bar_width, color='blue', label='Review Count')

# Set labels and title for the first y-axis
ax1.set_ylabel('Review Count')
ax1.set_title('Review Count and Rating by Bike Stations')

# Create a secondary y-axis
ax2 = ax1.twinx()

# Plot the ratings
ax2.plot(indices + bar_width / 2, ratings, marker='o', color='red', label='Average Rating')

# Set labels for the second y-axis
ax2.set_ylabel('Average Ratings')

# Set the x-axis tick positions and labels
ax1.set_xticks(indices)
ax1.set_xticklabels(bike_stations, rotation=45)

# Adjust the layout and spacing
fig.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the data
review_counts = [19838, 15907, 18702]
ratings = [4.03, 4.06, 4.04]
bike_stations = ['605 - Virginia St & Florida Ave', '606 - S Bayshor Dr & Aviation Ave', '608 - City Hall']

# Create a figure and axes
fig, ax = plt.subplots()

# Plot the review counts
ax.bar(bike_stations, review_counts, color='blue', label='Review Count')

# Plot the ratings as a line graph
ax.plot(bike_stations, ratings, color='green', marker='o', label='Rating')

# Set labels and title
ax.set_xlabel('Bike Stations')
ax.set_ylabel('Count / Rating')
ax.set_title('Review Count and Rating by Bike Stations')
ax.legend()

# Rotate the x-axis labels
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Save the DataFrame to a pickle file
All_3_Miami_Stations_Combined.to_pickle('All_3_Miami_Stations_Combined.pk')

# %%
station1combined_df.to_pickle('station1combined_df.pk')

# %% [markdown]
# Provide a visualization that you used as part of your EDA process. Explain the initial pattern or relationship you discoved through this visualization.

# %%
import matplotlib.pyplot as plt

# Define the color palette
colors = ['blue', 'green', 'red']

# Extract the category columns
category_columns = ['Category 1']
category_data = station1combined_df[category_columns]

fig = plt.figure(figsize=(9.5, 4))
# Plot the histogram for each category
for i, category in enumerate(category_columns):
    plt.hist(category_data[category], bins=80, color=colors[i], label=category)

# Set labels and title
plt.xlabel('POI Florida Avenue')
plt.ylabel('Frequency')
plt.title('POI Categories Florida Avenue')
#plt.legend()
plt.xticks(rotation=75)
# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the color palette
colors = ['green', 'red']

# Extract the category columns
category_columns = ['Category 1']
category_data = station2combined_df[category_columns]

fig = plt.figure(figsize=(9.5, 4))
# Plot the histogram for each category
for i, category in enumerate(category_columns):
    plt.hist(category_data[category], bins=80, color=colors[i], label=category)

# Set labels and title
plt.xlabel('POI Aviation Avenue')
plt.ylabel('Frequency')
plt.title('POI Categories Aviation Avenue')
#plt.legend()
plt.xticks(rotation=75)
# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the color palette
colors = ['red']

# Extract the category columns
category_columns = ['Category 1']
category_data = station3combined_df[category_columns]

fig = plt.figure(figsize=(9.5, 4))
# Plot the histogram for each category
for i, category in enumerate(category_columns):
    plt.hist(category_data[category], bins=80, color=colors[i], label=category)

# Set labels and title
plt.xlabel('POI City Hall')
plt.ylabel('Frequency')
plt.title('POI Categories City Hall')
#plt.legend()
plt.xticks(rotation=75)
# Display the plot
plt.show()

# %% [markdown]
# # Database

# %% [markdown]
# Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %%
import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect('C:/Users/sarah/LHL-Statistical-Modelling-with-Python/data/results.db')

# Save the merged_df dataframe to a table in the database
All_3_Miami_Stations_Combined.to_sql('All_3_Miami_Stations_Combined', conn, if_exists='replace', index=False)

# Close the database connection
conn.close()

# %% [markdown]
# Look at the data before and after the join to validate your data.

# %%
Looks Good!
