# %% [markdown]
# Build a regression model.

# %%
# Step 1: Prepare your data

# Load the DataFrame from the Miami Bikes pickle file
df = pd.read_pickle('All_3_Miami_Stations_Combined.pk')

# %%
df.describe()
# Out:
#          latitude   longitude  free_bikes  empty_slots  review_count  \
# count  150.000000  150.000000  150.000000   150.000000    150.000000
# mean    25.730078  -80.236423   11.666667     4.333333    362.980000
# std      0.001768    0.003693    3.694121     3.694121    424.444548
# min     25.728437  -80.241581    7.000000     0.000000     14.000000
# 25%     25.728437  -80.241581    7.000000     0.000000    105.500000
# 50%     25.729275  -80.234443   12.000000     4.000000    228.000000
# 75%     25.732522  -80.233244   16.000000     9.000000    349.000000
# max     25.732522  -80.233244   16.000000     9.000000   2247.000000
#
#            rating  coordinates.latitude  coordinates.longitude
# count  150.000000            150.000000             150.000000
# mean     4.043333             25.731682             -80.242269
# std      0.455896              0.027851               0.017375
# min      3.000000             25.725109             -80.444933
# ...

# %%
df = df[['latitude','longitude','free_bikes','empty_slots','review_count','rating','coordinates.latitude',
         'coordinates.longitude']]

# %%
#run full model using Backward Selection
y = df['free_bikes']  # Number of bikes is the target variable
X = df.drop('free_bikes', axis=1)  # predictor variables

X = sm.add_constant(X) #adds a column of 1's so the model will contain an intercept

model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             free_bikes   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 7.367e+23
# Date:                Sun, 04 Jun 2023   Prob (F-statistic):               0.00
# Time:                        20:24:54   Log-Likelihood:                 3475.6
# No. Observations:                 150   AIC:                            -6937.
# Df Residuals:                     143   BIC:                            -6916.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0302   1.41e-10   2.13e+08      0.000       0.030       0.030
# ...

# %%
#run full model using Backward Selection
y = df['free_bikes']  # Number of bikes is the target variable
X = df.drop(['free_bikes','review_count','rating','coordinates.latitude','coordinates.longitude'],  axis=1)  # predictor variables

X = sm.add_constant(X) #adds a column of 1's so the model will contain an intercept

model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             free_bikes   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.264e+24
# Date:                Sun, 04 Jun 2023   Prob (F-statistic):               0.00
# Time:                        20:11:56   Log-Likelihood:                 3475.3
# No. Observations:                 150   AIC:                            -6945.
# Df Residuals:                     147   BIC:                            -6936.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0302   1.37e-10   2.21e+08      0.000       0.030       0.030
# ...

# %%
dff = pd.read_pickle('station1combined_df.pk')

dff.describe()
# Out:
#            latitude     longitude  free_bikes  empty_slots  review_count  \
# count  5.000000e+01  5.000000e+01        50.0         50.0     50.000000
# mean   2.572927e+01 -8.024158e+01        16.0          0.0    396.760000
# std    3.588783e-15  1.004859e-13         0.0          0.0    453.853638
# min    2.572928e+01 -8.024158e+01        16.0          0.0     42.000000
# 25%    2.572928e+01 -8.024158e+01        16.0          0.0    124.500000
# 50%    2.572928e+01 -8.024158e+01        16.0          0.0    240.500000
# 75%    2.572928e+01 -8.024158e+01        16.0          0.0    405.750000
# max    2.572928e+01 -8.024158e+01        16.0          0.0   2247.000000
#
#           rating    distance  coordinates.latitude  coordinates.longitude
# count  50.000000   50.000000             50.000000              50.000000
# mean    4.030000  265.312177             25.728075             -80.242538
# std     0.421489  147.218626              0.001435               0.002008
# ...

# %%
dff=dff[['latitude','longitude','free_bikes','empty_slots','review_count','rating','coordinates.latitude',
         'coordinates.longitude']]

# %% [markdown]
# Provide model output and an interpretation of the results.

# %%
The R-squared and Adjusted R-squared values measure the goodness of fit of the regression model. 

A value of 1.000 suggests that the model explains all the variation in the dependent variable, which may indicate overfitting??? Few observations??

A p-value more than the chosen significance level - 0.05 suggests that the predictor variables – review count, rating,coordinates latlon has no  significant effect on the dependent variable.

# %% [markdown]
# # Stretch

# %% [markdown]
# How can you turn the regression model into a classification model?
